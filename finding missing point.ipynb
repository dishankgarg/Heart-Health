# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import pylab as pl

# %%
data = pd.read_csv('jainam_data.csv');

# %%
data
# Out:
#         4
# 0       0
# 1      11
# 2      22
# 3      32
# 4      32
# ...   ...
# 4238  278
# 4239  278
# 4240  278
# 4241  278
# 4242  278
#
# [4243 rows x 1 columns]

# %%
 plt.plot(data.iloc[0:10835,0])

# %%
peaks = []
for i in range(0,4000):
    if(data.iloc[i,0] >= 800):
        peaks.append(i)

# %%
data.iloc[1,0]
# Out:
# 11

# %%
length = len(data)

# %%
for i in range(length):
    if math.isnan( data.iloc[i,0]):
        data.iloc[i,0] = (data.iloc[i-1,0] + data.iloc[i+1,0])/2

# %%
ran = length/200
ran = int(ran)
for i in range (ran):
    plt.plot(data.iloc[i*200:(i*200 + 200),0])
    plt.show()

# %%
plt.plot(data.iloc[20500:20600,0])
plt.show()

# %%
df = pd.DataFrame(data)
excel_file_path = 'jainam_data.csv'  # Provide the path where you want to save the file
df.to_csv(excel_file_path, index=False)
